# %% [markdown]
# # Hardware Catalog
#
# Generated: 2025-07-30
#
# ---
#
# ## Summary Table
#
# | Device                      | Role                           | Model                                      | OS                               | CPU                                        | GPU(s)                         | RAM                          | Storage                                          | Virtualization               | Software                                  |
# |-----------------------------|--------------------------------|--------------------------------------------|----------------------------------|---------------------------------------------|--------------------------------|-------------------------------|---------------------------------------------------|------------------------------|-------------------------------------------|
# | Custom Tower PC           | Semantic anchor node           | Custom-built tower PC (ASRock H81 Pro BTC R2.0) | Windows 10 Pro                  | Intel 4th Gen (LGA1150; exact model TBD)    | NVIDIA RTX 2060 (6 GB GDDR6)   | 16 GB DDR3 (2×8 GB @1600 MHz) | 224 GB SATA SSD (ADATA SU630); SanDisk Ultra USB 3.0 | n/a                          | PowerShell, orchestration scripts        |
# | LG UltraGear 24GQ50F-B       | Primary display               | 24GQ50F-B                                  | n/a                              | n/a                                         | n/a                            | n/a                           | n/a                                               | n/a                          | n/a                                       |
# | HP Pavilion Gaming 15-ec0xxx | Secondary client               | Pavilion Gaming 15-ec0xxx                  | Windows 11                       | AMD Ryzen 5 3550H (4 c/8 t @ 2.1 GHz)        | Radeon Vega 8; GTX 1650        | 13.88 GB                      | C: 237.53 (11.95 GB free), D: 931.51 (880.87 GB free)                    | n/a                          | Amazon Q CLI                              |
# | HP ZBook 15 G3              | Tertiary client / test node    | ZBook 15 G3                                | Windows 10 Pro 2009 (19045)      | Intel Core i7-4900MQ (4 c/8 t @ 2.8–3.8 GHz) | Quadro K2100M; HD Graphics 4600 | 16 GB (2×8 GB DDR3-1600)      | 464.58 GB (213.37 GB free)                        | VMware (Ubuntu 18.04.3 guest) | Microsoft Office                         |
#
# ---
#
# ## Detailed Manifests
#
# ### Tower PC (RF Node)
#
# - Orchestration Role: Semantic anchor node for assistant deployment
# - Motherboard: ASRock H81 Pro BTC R2.0
# - CPU Socket / Model: LGA1150 – Intel 4th Gen support (exact CPU model TBD)
# - RAM: 16 GB DDR3 (2×8 GB @ 1600 MHz)
# - GPU: NVIDIA RTX 2060 – 6 GB GDDR6
# - PSU: MSI MAG A750GL – 750 W, PCIe 5.0 Ready
# - Case: ATX chassis; 2× 2.5″ SATA III drive bays
# - OS: Windows 10 Pro
# - Storage:
#   - Primary SSD: ADATA SU630 (Serial: 2K2020072458), SATA III 6 Gb/s, 224 GB
#   - Removable Media: SanDisk Ultra USB 3.0 (Serial: 4C530000140812103501), assumed 32–128 GB
# - Networking: Gigabit Ethernet
# - Virtualization: n/a
# - Software: PowerShell, live assistant traces, semantic-sync agent, evidence logging
#
# ---
#
# ### LG UltraGear 24GQ50F-B
#
# - Screen size: 23.6″, IPS panel, 1080p @ 144 Hz
# - Inputs: DisplayPort 1.2 × 1; HDMI 1.4 × 2
# - Features: FreeSync, built-in KVM switch, USB-B upstream
# - Serial number: 309AXVT05391 (09/2023)
#
# ---
#
# ### HP Pavilion Gaming 15-ec0xxx
#
# - Model: Pavilion Gaming 15-ec0xxx
# - OS: Windows 11 (edition & build TBD)
# - CPU: AMD Ryzen 5 3550H (4 c/8 t @ 2.1 GHz base; boost TBD)
# - GPUs: Radeon Vega 8; NVIDIA GeForce GTX 1650
# - Memory: 13.88 GB (modules & speed TBD)
# - Storage: C:/, D:/, E:/ (capacities pending)
# - Ports: HDMI 2.0 (others TBD)
# - Networking: Wi-Fi 6, Bluetooth 5.0 (pending)
# - Special software: Amazon Q CLI
#
# ---
#
# ### HP ZBook 15 G3
#
# - Model: ZBook 15 G3 mobile workstation
# - OS: Windows 10 Pro 2009 (build 19045)
# - CPU: Intel Core i7-4900MQ (4 c/8 t; 2.8 GHz base, up to 3.8 GHz boost)
# - GPUs: NVIDIA Quadro K2100M; Intel HD Graphics 4600
# - Memory: 16 GB (2×8 GB Samsung DDR3-1600)
# - Storage: 464.58 GB total (213.37 GB free; model & serial TBD)
# - Video outputs: DisplayPort, HDMI, USB-C alt-mode (versions TBD)
# - Virtualization: VMware Workstation running Ubuntu 18.04.3 guest (vCPU & RAM TBD)
# - Software: Microsoft Office
