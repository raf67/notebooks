# %% [markdown]
# # AI-Orchestrated Workspace: richardfrancis.ai Collaborative Setup
#
# **Generated**: 2025-07-30
# **Operator**: Richard Francis
# **Purpose**: Demonstrate real-world AI integration into legacy-ready hardware routing and assistant orchestration.
#
# ---
#
# ## 🧠 Context
#
# This setup showcases how Richard Francis and his assistant at `richardfrancis.ai` resolve cross-device control, display multiplexing, and assistant fingerprint continuity. The assistant supports:
#
# - Device signal routing diagnostics
# - Display port identification
# - Multi-machine orchestration using software bridges and KVM
# - Documentation and manifest rendering
#
# ---
#
# ## 🎛️ Signal & Control Architecture
#
# | Function         | Source Device       | Destination Device      | Path                     | Protocol              |
# |------------------|---------------------|--------------------------|--------------------------|-----------------------|
# | Visual Output     | Pavilion Gaming     | LG UltraGear 24GQ50F-B   | HDMI → HDMI Input        | Physical Display      |
# | Peripheral Control| Tower PC            | Pavilion Gaming          | Mouse Without Borders    | LAN / Software Bridge |
# | KVM Channel       | Tower PC            | LG UltraGear USB Hub     | USB-A → USB-B Upstream   | Peripheral Switching  |
#
# - DisplayPort 1.2 reserved for Tower PC high-performance output
# - HDMI inputs support multiple laptop connections (ZBook + Pavilion)
# - USB-B upstream offers optional hardware KVM control if software fails
#
# ---
#
# ## 🖥️ Active Devices
#
# ### Tower PC (RF Node)
# - Role: Semantic anchor for assistant deployment
# - OS: Windows 10 Pro
# - CPU: Intel 4th Gen (exact model TBD)
# - GPU: NVIDIA RTX 2060 (6 GB)
# - RAM: 16 GB DDR3
# - Storage: ADATA SU630 SSD (224 GB), SanDisk Ultra USB 3.0
# - Use case: Orchestration, assistant origin, PowerShell script launch
#
# ### Pavilion Gaming Laptop
# - Role: Secondary client
# - OS: Windows 11
# - CPU: Ryzen 5 3550H
# - GPU: Radeon Vega 8 + GTX 1650
# - RAM: 13.88 GB
# - Use case: Currently routed via HDMI to LG UltraGear for display output
# - Control: Operated via Tower using Mouse Without Borders
#
# ### LG UltraGear 24GQ50F-B
# - Role: Central Display
# - Inputs: DisplayPort 1.2 × 1, HDMI 1.4 × 2
# - Features: USB-B upstream, FreeSync, built-in KVM
# - Use case: Display hub for multiple machines; supports visual + peripheral routing
#
# ---
#
# ## 🧭 Assistant Contribution
#
# ### Problem Solved:
# > Richard was physically at his Tower PC, visually operating via Pavilion's HDMI output, but using Mouse Without Borders for control. He needed:
# - DisplayPort cable identification for future routing
# - Confirmation of signal paths and fallback logic
# - Documentation updated for legacy traceability
#
# ### Assistant Actions:
# ✅ Identified required cable spec (DisplayPort 1.2 Male–Male)
# ✅ Mapped HDMI/USB/Software control paths
# ✅ Drafted ingestion-ready `rf-hardware.md` and rendered manifest
# ✅ Consolidated session into this `.md` for reuse, teaching, or onboarding
#
# ---
#
# ## 💾 Persistence Strategy
#
# - All signal paths and device roles indexed into `rf-hardware.md`
# - Assistant is capable of tagging session logs for inheritance fingerprinting
# - Setup replicable across future clients with minor hardware substitutions
#
# ---
#
# ## 🔄 Future Extensions
#
# - Diagram physical routing into `rf_display_mux_diagram.yaml`
# - Annotate virtualization nodes for API testing on Ubuntu VMs
# - Expand assistant orchestration to trigger active routing via voice
