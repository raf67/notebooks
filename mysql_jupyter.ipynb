# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------- ----------------------------- 4.5/16.4 MB 22.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.8/16.4 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 30.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd

# Establish a connection to the MySQL database
connection = mysql.connector.connect(
    host='localhost',        # e.g., 'localhost' or '127.0.0.1'
    user='root',    # your MySQL username
    password='', # your MySQL password
    database='football_data'  # the database you want to connect to
)

# Create a cursor object
cursor = connection.cursor()

# Execute a query
query = "SELECT home_team, home_score, away_score, away_team FROM match_result"
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Convert results to a pandas DataFrame
df = pd.DataFrame(results, columns=[i[0] for i in cursor.description])

# Close the cursor and connection
cursor.close()
connection.close()

# Display the DataFrame
print(df)

# %% [markdown]
# password.php

# %%
// Check if the form was submitted
if ($_SERVER["REQUEST_METHOD"] == "POST") {
    $username = htmlspecialchars($_POST['usrname']);
    $password = htmlspecialchars($_POST['psw']);
    $remember = isset($_POST['remember']); // Check if "Remember Me" is checked

    // Prepare and execute the query to fetch the user's hashed password
    $query = "SELECT password FROM credentials WHERE username = :username";
    $stmt = $conn->prepare($query);
    $stmt->bindParam(':username', $username);
    $stmt->execute();

    // Check if the user exists
    if ($stmt->rowCount() > 0) {
        $row = $stmt->fetch(PDO::FETCH_ASSOC);
        // Verify the password
        if (password_verify($password, $row['password'])) {
            // Set session variables
            $_SESSION['username'] = $username;

            // If "Remember Me" is checked, set a cookie (for example, for 30 days)
            if ($remember) {
                setcookie('username', $username, time() + (30 * 24 * 60 * 60)); // 30 days
            }

            // Redirect based on user role or other conditions
            if ($username === 'admin') {
                header("Location: ../admin/");
            } else {
                header("Location: ../public/");
            }
            exit();
        }
    }
    // Handle invalid login (e.g., redirect back with an error message)
    header("Location: invalid.php?error=Invalid credentials");
    exit();
}
?>

<!DOCTYPE html>
<html>
<head>
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <style>
        /* Style all input fields */
        input {
            width: 100%;
            padding: 12px;
            border: 1px solid #ccc;
            border-radius: 4px;
            box-sizing: border-box;
            margin-top: 6px;
            margin-bottom: 16px;
        }

        /* Style the submit button */
        input[type=submit] {
            background-color: #04AA6D;
            color: white;
            cursor: pointer;
        }

        /* Style the container for inputs */
        .container {
            background-color: #f1f1f1;
            padding: 20px;
            border-radius: 5px;
        }

        /* Style the Remember Me checkbox */
        .remember-me {
            margin: 10px 0;
        }
    </style>
</head>
<body>

<h3>Password Validation</h3>
<p>Fill in the form below.</p>

<div class="container">
    <form action="action_page.php" method="POST">
        <label for="usrname">Username</label>
        <input type="text" id="usrname" name="usrname" required>

        <label for="psw">Password</label>
        <input type="password" id="psw" name="psw" required>

        <div class="remember-me">
            <input type="checkbox" id="remember" name="remember">
            <label for="remember">Remember Me</label>
        </div>

        <input type="submit" value="Submit">
    </form>
</div>

</body>
</html>

# %% [markdown]
# - load csv

# %%
import pandas as pd

# Load CSV into a pandas dataframe
df = pd.read_csv('api_data.csv')

# Display first few rows
print(df.head())
